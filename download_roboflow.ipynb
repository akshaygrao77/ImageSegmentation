# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="jMum6n4dFvT3Wjg9lcg6")
project = rf.workspace("damage-detection-d25qu").project("vehicle-damage-detection-hhxfj")
version = project.version(1)
dataset = version.download("coco-segmentation")
# Out:
# ...
#      |████████████████████████████████| 58 kB 6.3 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 49.1 MB 39 kB/s  eta 0:00:011
# ...
#      |████████████████████████████████| 58 kB 34 kB/s s eta 0:00:01
# ...
#      |████████████████████████████████| 67 kB 6.7 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 55 kB 3.6 MB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 178 kB 12.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 155 kB 11.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 54 kB 3.8 MB/s  eta 0:00:01
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="jMum6n4dFvT3Wjg9lcg6")
project = rf.workspace("dan-vmm5z").project("car-damage-coco-dataset")
version = project.version(9)
dataset = version.download("coco-segmentation")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to car-damage-coco-dataset-9 in coco-segmentation:: 100%|██████████| 1704/1704 [00:00<00:00, 4214.45it/s]
